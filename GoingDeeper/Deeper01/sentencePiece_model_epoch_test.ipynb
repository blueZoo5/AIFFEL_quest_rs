# %%
import os

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %matplotlib inline

# %%
# 네이버 리뷰 파일 불러오기

path_to_file = 'data/ratings_train.txt'

with open(path_to_file, "r") as f:
    raw = f.read().splitlines()

print("Data Size:", len(raw))

print("Example:")
for sen in raw[0:100][::20]: print(">>", sen)
# Out:
# Data Size: 150001
# Example:
# >> id	document	label
# >> 3989148	약탈자를 위한 변명, 이라. 저놈들은 착한놈들 절대 아닌걸요.	1
# >> 4805788	이 영화가 왜 이렇게 저평가 받는지 모르겠다	1
# >> 8317483	백봉기 언제나오나요?	1
# >> 9801316	아햏햏 아햏햏 아햏햏.	1

# %%
# 전체 문장의 최소/최대 길이 확인

min_len = 999
max_len = 0
sum_len = 0

for sen in raw:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(raw))

sentence_length = np.zeros((max_len), dtype=int)

for sen in raw:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 8
# 문장의 최장 길이: 168
# 문장의 평균 길이: 45

# %%
# 문장 길이가 10 이하인 문장 확인
def check_sentence_with_underlength(raw, length):
    count = 0
    
    for sen in raw:
        if len(sen) <= length:
            print(sen)
            count += 1
            
    print('\n')
    print(f"문장 길이 {length} 이하인 문장개수 {count}")

check_sentence_with_underlength(raw, 10)
# Out:
# 304515	음	1
# 444938	k	1
# 20433	gg	0
# 132033	음	0
# 181912	!	1
# 359141	굿	1
# 216228	.	0
# 2172111		1
# 24994	ㅇㅇ	0
# 323254	시	1
# 104253	굿	1
# 2350	별로	0
# 669245	굿	1
# 864206	굿	1
# 6369843		1
# 684649	굿	1
# 420354	1	0
# 288847	굿	0
# 192388	굿	1
# 656578	굿	1
# 96210	강추	1
# 596948	굿	0
# 30570	10	1
# 58414	고전	0
# 11046	b	0
# 129589	g	1
# 81044	大作	1
# 15565	ㅡㅡ	0
# 6859	짱	1
# 417105	즐	0
# 298858	굿	1
# 697084	굳	1
# 200387	g	0
# 25038	ㅉㅉ	0
# 202066	음	0
# 1034280		0
# 461077	굿	1
# 200855	굿	1
# 168734	h	1
# 20438	굿!	1
# 371946	굳	1
# 5942978		0
# 76131	ㄱ	0
# 843536	.	0
# 101208	k	0
# 571771	즐	0
# 404477	a	1
# 1034283		0
# 363915	.	0
#
#
# 문장 길이 10 이하인 문장개수 49

# %%
# 문장 길이가 150 이상인 문장 확인
def check_sentence_with_uplength(raw, length):
    count = 0
    
    for sen in raw:
        if len(sen) >= length:
            print(sen)
            count += 1
            
    print('\n')
    print(f"문장 길이 {length} 이상인 문장개수 {count}")

check_sentence_with_uplength(raw, 150)
# Out:
# 9837767	데너리스 타르 가르엔...나도 용의주인이 되고 싶다...누이랑,근친상간이나 하고 다닐지라도,소설 속에선 제일 멋진 놈이 자이메 라니스터였는데,드라마속에선,드래곤(용)이 제일 멋지네(웃음)감독님 토르-2 다크 월드는 말아 잡수셨을지라도,기본 선방은 했음	1
# 10099353	중국의 어거지 로마 마을 광관홍보영화. 중국에 있는 저 로마마을에 가면 로마에 있는 돈 받고 같이 사진찍어주는 로마병사코스프레를 따라한 중국할배들이 돌아다님 ㅋ 실화는 개뿔 학자들에 의하면 로마인들이 저 지역에 단체이주해 살았다는 역사적 근거는 전무함	0
# 8559095	마치 하수구가 막혀 물이 내려가지 못하는 답답한 스토리?....같은 자리를 뱅뱅 도는 듯한 느낌...배우의 문제가 아니라 스토리가 문제 있는듯...밑에 10점 주신분들 주관적이기야 하겠지만...10점은 아닌듯...좀 시원하게 진행 좀 됐으면..질질질.	0
# 8142394	소재는 기발했다. 하지만 그 이상의 뭔가를 보여주지못하고, 이 참신한 설정의 무대에서 놀고 있는 캐릭터들은 길을 못 찾고 어느 쪽으로 가야할지 허둥대는 상황만 보여준다. 사람들이 어둠속으로 사라질때 옷만 남겨놓듯 이 영화도 설정만 남겨놓고 사라진것같다	0
# 10056886	감독 세르게이 보드로프...우베 볼이 감독 너에게 아따 행님요~하게 생겼다...(웃음)스티븐 시갈 영화들이,바람과함께 사라지다나,전쟁과평화처럼 보이게 하는 것도 재주 라면 재주...인디펜던스 데이 이후에 이 정도 발로 쓴 시나리오 정말 오랜만에 본다.	0
# 6878666	이혜영 강남에서,10여년전에 한번 봤는데,007처럼,은색 재규어 몰고 다니더라.방송일만 하면,개나소나 다 끌고다니는 외제차 아직 한번도 못뽑아 봤으니,참.인생 왜 사나 싶다.그게 무슨 캡슐에서 뽑는,갸차폰 완구도 아니고,다들 재주도 좋네.쉽게 뽑으니.	0
# 10141871	"""배우들 연기 :10점, 연출 :10점 , 스토리 : 10노잼 .. 내용이 짜집기가 안될거같을때 주인공이 """"이건현실이 아니야!!"""" 한마디하면서 게속 얼렁뚱땅 넘어가는느낌? 보는데 진짜 찝찝;; 내용이 앞뒤는 안맞고 뭐 자꾸 이건현실이 아니라면서넘어가니"""	0
# 9467073	여기 호감순보면 순 친일파에 알지도 못하는 사무라이 역사를 말하고있네. 이 영화는 옛 사무라이의 더러운 것들을 미화시켜서 내논 영화입니다. 군사철학은 없고 단지 주군에 충성한 살인청부업자들이 모인 단체입니다. 글을 읽을줄 아는사람도 별로 없다고 하네요	0
# 9215462	룸메이트 1기 그냥 그데로 했으면 좋겠는데 ㅠㅠㅠㅠ 1기 룸메이트 했던 사람들이 더 좋았는데 ㅠ이렇게 아쉽게 가버린다니 ㅠ 평생 잊지 못할거예요 ㅠ 그냥 1기때처럼 그데로 해줬으면 좋겠는데 ㅠ제발 우리곁에 떠나지마요 ㅠ안가면 안되나? 보고싶을 거예요ㅠ	0
# 7513670	생뚱,엉뚱,갸우뚱한 상상력에 엉성하기 그지없는 전개, 한 마디로 실망 그자체입니다.제목은 진지한데 웃을래야 웃을 수 없는 일그러진 희극을 보는 것 같군요.마음을 따뜻하게 하는 드라마가 사라지고 말초신경만 자극하는 드라마가 판치는 시대의 일그러진 자화상	0
# 6887090	막장...맛이 가도,한참 갔어...이건 멘토가 아니라,음악학원원장이네.원생 챙기는것도 아니고,멘토들끼리,같잖은 감정싸움에,말꼬리 붙들고 늘어지기에,아 ~작가들 대본 좀 잘 쓸수 없어요?.MB씨(?)개그의 종착역.강호동씨의 개그맨시절이 그리워질 지경이다	0
# 8441525	"""너무 충격적입니다. 어떻게 이런걸 영화라고 내놓나요? 보는내내 물음표만 가득했습니다. 남자가 여자 못들때 """"???"""" 엄마가 시도때도없이 자기야할때 """"???"""" 남자 풀어줄때""""???"""" 신고하러가서 그냥올때 """"????"""""""	0
# 9129855	현실적인 군대사회를 보여주지 못하고 미화시킨다는 의견으로 시청 안하다가 여군특집을 한다기에 기대감에 봤는데 짐싸는시간에 꿀호떡먹었다고 얼차려라니... 위생때문에 실내에서 취식금지? 인권이 무시되는 군대를 적나라하게 보여주긴하는데 보기 힘들어서 채널돌림	0
# 9951618	내 생에 최고의 영화중 하나입니다. 러셀크로우의 유머스러운 악연기로 보는 내내 웃음을 참느라 고생했습니다. ^_^ 정말 웃기는 장면에선 숨막히게 웃기고 재미있습니다. 옛날에 한번보고 기억나서 블루레이로 사서 다시 보고 있습니다. 여전히 멋지고 웃깁니다	1
# 9700965	내 인생 최고의 영화였다.보는 내내 삶의 이유,양심,신념 등등에 대해 많은 생각을 하게 만드는 걸작이었다.특히 마지막 장면을 보면서 깊은 감동으로 눈물이 쏟아지더라.자신의 양심과 신념을 지키며 사는 삶이 여인의 향기와 같다고 제목을 통해 비유한 것같다	1
# 9922254	책을 보고 너무 기대했었는데 책에서는 다 캣니스 시점에서 서술하고 캣니스의 심리를 다 보여줬던 반면에 영화에서는 캣니스 시점을 통해서가 아닌 그냥 그 상황을 보여주려고 해서 새략된게 너무 많고 내용이 뚝뚝끊김.. 아쉬움.. 고작 이 정도 연출이라니ㅠㅠ	0
# 9554058	애니 기본 전개는 저연령층 대에서 보기에는 흥미있고 재미 있을듯 한데 ... 더빙 완전 안습이다 ..ㅠㅠ ;; 목소리 연기는 둘째치고 ;; 뭔 의역을 이래 심하게 했을까.. 처음부터 나오는 성형언니들 드립부터 너무 황당ㅋ 원본이 영어면 더빙 안봣다ㅡㅡ	0
# 6780365	일본 애니메이션의 수준은 패전후 내적고민과 갈등에서 출발한다. 일부 일본 우익 정치인들의 역사관은 잘못됐다 하더라도 애니메이션 작가들의 사회에 대한 인식수준은 참으로 놀랍다. 한국의 애니가 따라가려면 멀었다는 것이다. 청소년들이 이해하긴 어려울 것..	1
# 9801137	평점이 6.91..? 누가 장난쳐논거 아님? 이영화가어떻게 6점밖에 안되냐? 난 원래 한국영화 안좋아하는데 이건 다시봐도 재미있고 옛날 학교다니던 추억도 생각나고 좋더만.그리고 은근슬쩍 정치판 까는것도 좋았고..무엇보다 유해진이랑 차승원 연기 너무잘함	1
# 7990669	내용은 굉장히 좋은데.. 개인적으로 홍상수감독은 연출법에 대해 굉장한 의구심을 갖게한다.. 왜 구지 A급 각본을 쓰고 B급영화를 찍으려 하는걸까? 순수한 알맹이 자체로만 보이길 바라는건지... 껍데기를 씌울 자신이 없는건지... 나에겐 맞지않는 영화.	0
# 6824523	가끔하는 재방 보는데..진짜 어이가 없다! 딸래미 찾는 중요한 유전자 검사를 피도 아닌 본인들이 직접 참석도 안 한 상태에서..머리카락 이락 칫솔로 검사를 하냐! 그리고 백소장 인가 하는 사람 유전자 저보는 기록되 있지 않나..본인 동의하에 가서 검사	0
# 10153696	와~ 슈퍼액션에서하길래봤는데.... 이 저질스런영화는뭘까..천만이라는거보고더열받친다내가열낼일은아닌데ㅋㅋ사람들이수영도다못하고장애물잡을지모르고...정상인이몇명없다...문제는스토리를억지로짜내서만들려고사람들을정신병자로만든다..그래서병자집합소느낌나는영화다...	0
# 6601801	정말... 무미건조한 액션영화다. 영화관 가서 봤으면 화났을 듯.. 저예산 영화라니 그러려니 합니다. 테이큰이랑 아저씨까지 끌어들이는 건 너무..비교대상이 아니지 않나? 화면이나 사운드는 구렸지만 그래도 정석원씨 미니멀한 의상 하나는 참 잘어울립디다.	0
# 9085196	아무리 재미가 없어도 재미 없다는 말을 내뱉는 순간 영화 볼줄 모르는 무식한 인간 취급을 받게 된다는 임권택 영화 .... 도대체 어느 부분에서 감동하고 어느 부분에서 공감해야 하는지조차 모를 정도로 엉성한 영화에 온갖 과대 포장만 잔뜩 붙여놓은 영화	0
# 6976829	정말 몰입해서 봤던 영화입니다. 군인 정말대단하다는생각바께안들고요 아멋집니다. 특히마지막 여자가 아직 살아있는 두명 찾기전엔 못떠난다고했을때 한번 제독이 바로업어가는장면에 한번 마지막으로 찾아서 군인이 손들었을때 전율을 느꼈습니다 감동이란 이런겁니다.	1
# 10258831	약간 전개가 빠른듯하지만 그래도 감정이입충만했던영화. 지난날의 아픔을 여전히 갖고있는 그 가족과 후손들에게 빼앗긴것을 돌려주고 무엇보다 잘못을 인정하고 정식적인 사과가 필요한것같다.. 다시금 나치와같은일이 역사에 등장해선 안된다는 생각을 들게한 영화	1
# 9187873	오랜만에 만난, 가슴이 먹먹해지는 영화. 원작이 따로 있는데 내용이 쓰레기라고 욕하는 사람들은 뭐지? 현실성 여부를 떠나서, 사랑에 대한 색다른 관점을 통해 현재의 나에 대해 고민해 볼 수 있어서 좋았다. Foolish Blues 들으면서 센티 씹는중	1
# 9779287	세상에...; 내 살다살다 이런 쓰레기같은 영화는 또 첨보네...빙하가 도시를 덮친다는 스토리는 그렇다 쳐도 이 허접한 CG와, 눈이 왔으면 도로에도 눈이 쌓여야 정상인데, 도로 가장자리만 눈이 쌓여있고 도로는 깨끗하네 ㅋㅋㅋ 누군가가 청소라도 했나?	0
# 6823059	"""범인 잡는 추리드라마였나!!....음 처음이내요 이런글 올려보는거...오죽하면...^^"""""""""""" 새끼 꼬듯 넘 끌지안으시는게... 것도 친자확인가지고... 이건 아니다싶내요.^^"""" 시청자가 보면서앞으로의 스토리를 예상할정도면... 에궁"""	0
# 6499993	국민 대다수가,게이,레즈비언친구도 하나없는,우리나라같은데서?미혼녀를 소재로?시청률대박을 노리시겠다고요?그것도 상큼발랄한 로맨틱코미디로?차라리 제가 브루스 리 대역으로 사망유희를 다시 찍어서,극장에서,아바타도 한번 꺾어보겠습니다.이나라안에서만이라도...	0
# 10142748	영화 개츠비를 보고났을때 느꼈던 것은 돈, 명예 , 욕망 그리고 사랑이 얼마나 덧없고 인정머리 없는 것인지를 똑똑히 느끼게 해주었다. 데이지의 전화벨 소리를 들었을때 순진하게 고개를 들었던 개츠비, 아마도 영화속에서 가장 순수한 인물이 아니지 않을까?	1
# 9795525	"""바다를 보러 오기까지 위험천만한 일 투성이었다. 경찰과 갱에 쫒기고 은행을 털고 인질극을 벌이기도 하고... 그런 과정을 겪었는데 더 두려울께 있나? """"두려울 것 하나도 없어."""" 내일 내가 죽는다면 오늘 나는 무엇을 해야하는가? 바다, 데낄라, 담배"""	1
# 8782050	12부. 남은 1회분까지 모두 본방사수할 생각이다. 아쉬운 한주가 지나면 더이상 코스모스를 볼 수 없다는 허탈감에 벌써부터 슬프다. 지식이면 지식에 상상력과 교훈까지 모든 걸 갖춘 코스모스는 여러 관점을 정확하게 알려줬다. 최고이자 최후의 다큐멘터리다	1
# 9647448	반전이고 나발이고 간에 후반부에 도달하기까지 너무 지루함. 진짜 토나올 정도.. TV 단막극보다 못한 최악의 스토리 텔링. 게다가 차태현식 코믹연기는 또 왜이렇게 물리는지.. 반전에 이르기까지 몰입감을 유도하는 내러티브의 힘이 전혀 없는 망작, 쓰레기	0
# 7061883	블레이드 1원 수작이었는데.. 암울한 분위기 하며, 캐릭터성은 말할것도 없고,2편은 좀 밝아진 분위기에 액션을 강조하여 1편보다 분위기가 좀 죽었고..그래도나름 분위기는 좋았는데..이3편은 너무실망..전편들은 아주 죽여놓고..나오지 말았어야..4편은?	0
# 10253254	진심 이영화 진짜 역대급에 들정도로 3류 미국 성인영화 내용에 진지함 한스푼 추가, 선정성 2스푼 빼서 만든 이도저도 아닌 쓰레기. 정말 댓글 잘 안다는데 너무 억울해서 댓글 2개 쓴다. 심지어 연속 댓글도 불가능한데 기다렸다가 쓸 정도. 다른 피해자	0
# 8645353	재미있는데. 몇몇 사람들이야 말로 다른 배트맨시리즈로 이 영화에 이상한기대를 하고 있는거 같다. B급유머와 베트크레딧카드 ㅋ배트맨시리즈 중 이렇게 유쾌한 시원한 내용을 담은 영화가 또 있을까. 진짜 무슨 개똥철학에 대한 이상한 기대만 아니면 재밌는영화	1
# 9509511	별 1점도 아까워요. 시간낭비함. 여배우들 얼굴은 야매로 한건지 성형중독인건지 보는내내 부담스러웠고, 오광록배우연기생활 하셨던 분이 대사읊는 실력이 책읽는줄알았어요. 감정몰입 하나도안됐구요. 여배우들 연기 진짜 못 봐줄만큼 최악이네요. 제작비가 아까움	0
# 7090308	멋진 영화는 결코 스토리와 극본이 다가 아니라고 생각합니다. 정말 멋진 영화는 장면 장면의 소중함, 대화 하나 하나의 의미, 그리고 생각해볼 만한 진지한 문제를 던져 준다면 더욱 좋겠죠. 인간의 내면을 탐구한 큐브릭의 이 작품은 그런면에서 걸작입니다.	1
# 7083866	@공동경비구역@JSA이전의박찬욱은 재기만 발랄했었지...그것도 순,치기에 가까운...얼치기 헐리우드 키드의 습작영화라고나 할까?데뷔작 달은 해가 꾸는 꿈 에이은,영화학도 박찬욱의 좌충우돌 영화현장경험기.이때의경험은,고스란히 싸이보그지만,괜찮아로 이어짐	0
# 8459771	처음엔 아기에게 반해서 마냥 흐뭇하게 웃다가, 대한민국 교육시스템에 대해 고민해보게 되고, 가족이 화해하는 모습에서 우리 가족이 보여 울다가 가족이 역이민을 결정한 이유를 듣고 그 당시 한국의 시대적 상황까지 돌아보게 되는 훌륭한 사적/공적 다큐영화!	1
# 6798178	그리 만족스럽진못했어도 7점은 나와야되는것같아 10점줌. 주인공들연기도 훌륭했고 내용도 이정도면 괜찮았다. 해피엔딩으로끝났으면 그저 진부한영화가 되버릴뻔. 그래도 엔딩이 섭섭한건 없지않아있었음. 킬러들의도시도그렇고 콜린파렐을 너무 축축하게 끝내버리는듯	1
#
#
# 문장 길이 150 이상인 문장개수 1148

# %%
# 중복된 문장 제거(중복 문장 없음)
min_len = 999
max_len = 0
sum_len = 0

cleaned_corpus = list(set(raw))  # set를 사용해서 중복을 제거
print("Data Size:", len(cleaned_corpus))

for sen in cleaned_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(cleaned_corpus))

sentence_length = np.zeros((max_len), dtype=int)

for sen in cleaned_corpus:   # 중복이 제거된 코퍼스 기준
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# Data Size: 150001
# 문장의 최단 길이: 8
# 문장의 최장 길이: 168
# 문장의 평균 길이: 45

# %%
# 최소길이 10, 최대길이 150으로 선정

max_len = 150
min_len = 10

filtered_corpus = [s for s in cleaned_corpus if (len(s) < max_len) & (len(s) >= min_len)]

sentence_length = np.zeros((max_len), dtype=int)

for sen in filtered_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()

# %%
import sentencepiece as spm

# %%
# ngram 모델로 토큰 학습

temp_file_ngram = 'data/ratings_train_sp_ngram.txt'

vocab_size = 8000

with open(temp_file_ngram, 'w') as f:
    for row in filtered_corpus:
        f.write(str(row) + '\n')

spm.SentencePieceTrainer.Train(
    '--input={} --model_prefix=korean_spm_ngram --vocab_size={}'.format(temp_file_ngram, vocab_size)    
)
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=data/ratings_train_sp_ngram.txt --model_prefix=korean_spm_ngram --vocab_size=8000
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/ratings_train_sp_ngram.txt
#   input_format:
#   model_prefix: korean_spm_ngram
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: data/ratings_train_sp_ngram.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 148849 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=6762891
# trainer_interface.cc(477) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1624
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 148849 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 487491 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 148849
# trainer_interface.cc(537) LOG(INFO) Done! 496504
# unigram_model_trainer.cc(489) LOG(INFO) Using 496504 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=232647 obj=15.3979 num_tokens=1113680 num_tokens/piece=4.78699
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=209963 obj=14.2956 num_tokens=1120641 num_tokens/piece=5.33733
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=157352 obj=14.3413 num_tokens=1148996 num_tokens/piece=7.30207
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=156649 obj=14.2603 num_tokens=1150009 num_tokens/piece=7.34131
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=117477 obj=14.4076 num_tokens=1186803 num_tokens/piece=10.1024
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=117304 obj=14.3344 num_tokens=1187808 num_tokens/piece=10.1259
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=87977 obj=14.4818 num_tokens=1223705 num_tokens/piece=13.9094
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=87863 obj=14.4272 num_tokens=1223906 num_tokens/piece=13.9297
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=65897 obj=14.631 num_tokens=1266962 num_tokens/piece=19.2264
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=65897 obj=14.5792 num_tokens=1267155 num_tokens/piece=19.2293
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=49422 obj=14.8459 num_tokens=1319197 num_tokens/piece=26.6925
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=49422 obj=14.7876 num_tokens=1319661 num_tokens/piece=26.7019
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=37066 obj=15.0958 num_tokens=1377760 num_tokens/piece=37.1705
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=37066 obj=15.0305 num_tokens=1378601 num_tokens/piece=37.1931
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=27799 obj=15.37 num_tokens=1443484 num_tokens/piece=51.9258
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=27799 obj=15.2956 num_tokens=1444153 num_tokens/piece=51.9498
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=20849 obj=15.6646 num_tokens=1514166 num_tokens/piece=72.6254
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=20849 obj=15.58 num_tokens=1514251 num_tokens/piece=72.6294
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=15636 obj=15.9742 num_tokens=1587560 num_tokens/piece=101.532
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=15636 obj=15.8725 num_tokens=1587576 num_tokens/piece=101.533
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=11727 obj=16.2945 num_tokens=1666372 num_tokens/piece=142.097
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=11727 obj=16.1921 num_tokens=1666423 num_tokens/piece=142.101
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=8800 obj=16.6724 num_tokens=1739514 num_tokens/piece=197.672
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=8800 obj=16.5674 num_tokens=1739696 num_tokens/piece=197.693
# trainer_interface.cc(615) LOG(INFO) Saving model: korean_spm_ngram.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: korean_spm_ngram.vocab

# %%
# bpe 모델로 토큰 학습

temp_file_sp_bpe = 'data/ratings_train_sp_bpe.txt'

with open(temp_file_sp_bpe, 'w') as f:
    for row in filtered_corpus:
        f.write(str(row) + '\n')

spm.SentencePieceTrainer.Train(
    '--input={} --model_prefix=korean_spm_bpe --vocab_size={} --model_type=bpe'.format(temp_file_sp_bpe, vocab_size)    
)
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=data/ratings_train_sp_bpe.txt --model_prefix=korean_spm_bpe --vocab_size=8000 --model_type=bpe
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/ratings_train_sp_bpe.txt
#   input_format:
#   model_prefix: korean_spm_bpe
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: data/ratings_train_sp_bpe.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 148849 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=6762891
# trainer_interface.cc(477) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1624
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 148849 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 148849
# tra

# %%
# ngram 모델 학습결과 확인
sp_ngram = spm.SentencePieceProcessor()
sp_ngram.load('korean_spm_ngram.model')

text = "자연어 처리를 배우고 있어요"
tokens = sp_ngram.encode_as_pieces(text)
print(tokens)
# Out:
# ['▁자연', '어', '▁', '처리', '를', '▁배우', '고', '▁있어요']
# iner_interface.cc(537) LOG(INFO) Done! 496504
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=102441 min_freq=89
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=12873 size=20 all=106758 active=8733 piece=▁정
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9743 size=40 all=109756 active=11731 piece=▁있
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7645 size=60 all=114335 active=16310 piece=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7192 size=80 all=115596 active=17571 piece=▁대
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5763 size=100 all=118695 active=20670 piece=24
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=5728 min_freq=91
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5133 size=120 all=122251 active=9410 piece=드라마
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4299 size=140 all=125177 active=12336 piece=▁느
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3807 size=160 all=128886 active=16045 piece=▁드라마
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3399 size=180 all=131272 active=18431 piece=▁내용
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3016 size=200 all=133711 active=20870 piece=▁쓰레기
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2986 min_freq=84
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2784 size=220 all=135587 active=8431 piece=▁100
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2585 size=240 all=137895 active=10738 piece=입니다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2378 size=260 all=140404 active=13247 piece=▁없는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2229 size=280 all=142677 active=15518 piece=▁하나
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2085 size=300 all=145375 active=18215 piece=▁몰
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2084 min_freq=77
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1938 size=320 all=147795 active=9645 piece=▁아깝
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1832 size=340 all=150906 active=12755 piece=연기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1749 size=360 all=152974 active=14822 piece=30
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1663 size=380 all=154777 active=16625 piece=▁많이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1548 size=400 all=156904 active=18751 piece=▁여자
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1541 min_freq=69
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1455 size=420 all=159087 active=9904 piece=▁귀
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1391 size=440 all=160625 active=11442 piece=▁설
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1329 size=460 all=162829 active=13646 piece=▁망
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1281 size=480 all=164967 active=15784 piece=▁다른
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1219 size=500 all=166520 active=17337 piece=▁스릴
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1213 min_freq=64
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1187 size=520 all=168426 active=10194 piece=▁선
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1136 size=540 all=170440 active=12208 piece=는지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1084 size=560 all=172243 active=14011 piece=48
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1048 size=580 all=173926 active=15694 piece=02
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1012 size=600 all=175440 active=17208 piece=▁67
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1010 min_freq=59
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=966 size=620 all=177559 active=10824 piece=▁올
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=937 size=640 all=178971 active=12236 piece=08
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=897 size=660 all=180612 active=13877 piece=▁102
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=873 size=680 all=18247

# %%
# bpe 모델 학습결과 확인

sp_bpe = spm.SentencePieceProcessor()
sp_bpe.load('korean_spm_bpe.model')

text = "자연어 처리를 배우고 있어요"
tokens = sp_bpe.encode_as_pieces(text)
print(tokens)
# Out:
# ['▁자연', '어', '▁처', '리를', '▁배우', '고', '▁있어요']

# %%
# ngram모델 단어집합의 상위 20개 단어
for i in range(20): 
    print(f"ngram 인덱스별 단어 {i}: {sp_ngram.id_to_piece(i)}")
# Out:
# ngram 인덱스별 단어 0: <unk>
# ngram 인덱스별 단어 1: <s>
# ngram 인덱스별 단어 2: </s>
# ngram 인덱스별 단어 3: ▁
# ngram 인덱스별 단어 4: ▁1
# ngram 인덱스별 단어 5: ▁0
# ngram 인덱스별 단어 6: .
# ngram 인덱스별 단어 7: ▁9
# ngram 인덱스별 단어 8: ..
# ngram 인덱스별 단어 9: 이
# ngram 인덱스별 단어 10: ▁영화
# ngram 인덱스별 단어 11: ...
# ngram 인덱스별 단어 12: ▁8
# ngram 인덱스별 단어 13: 의
# ngram 인덱스별 단어 14: 가
# ngram 인덱스별 단어 15: 도
# ngram 인덱스별 단어 16: 는
# ngram 인덱스별 단어 17: ▁7
# ngram 인덱스별 단어 18: 을
# ngram 인덱스별 단어 19: ,

# %%
# bpe모델 단어집합의 상위 20개 단어
for i in range(20): 
    print(f"ngram 인덱스별 단어 {i}: {sp_bpe.id_to_piece(i)}")
# Out:
# ngram 인덱스별 단어 0: <unk>
# ngram 인덱스별 단어 1: <s>
# ngram 인덱스별 단어 2: </s>
# ngram 인덱스별 단어 3: ▁1
# ngram 인덱스별 단어 4: ▁0
# ngram 인덱스별 단어 5: ..
# ngram 인덱스별 단어 6: 영화
# ngram 인덱스별 단어 7: ▁영화
# ngram 인덱스별 단어 8: ▁이
# ngram 인덱스별 단어 9: ▁9
# ngram 인덱스별 단어 10: ▁아
# ngram 인덱스별 단어 11: ▁8
# ngram 인덱스별 단어 12: ...
# ngram 인덱스별 단어 13: ▁그
# ngram 인덱스별 단어 14: ▁보
# ngram 인덱스별 단어 15: ▁재
# ngram 인덱스별 단어 16: ▁7
# ngram 인덱스별 단어 17: ▁10
# ngram 인덱스별 단어 18: ▁6
# ngram 인덱스별 단어 19: ᄏᄏ

# %%
text = "아, 이 영화 진짜 노잼인거 같음 ㅋㅋㅋㅋㅋ 주인공도 별로고 줄거리는 진짜 말도 안돼..."

print('ngram 출력 : ', sp_ngram.encode_as_pieces(text))
print('\n')
print('bpe 출력 : ', sp_bpe.encode_as_pieces(text))
# Out:
# ngram 출력 :  ['▁아', ',', '▁이', '▁영화', '▁진짜', '▁노잼', '인거', '▁같음', '▁ᄏᄏᄏᄏᄏ', '▁주인공', '도', '▁별로', '고', '▁줄거리', '는', '▁진짜', '▁말도', '▁안돼', '...']
#
#
# bpe 출력 :  ['▁아', ',', '▁이', '▁영화', '▁진짜', '▁노잼', '인거', '▁같음', '▁ᄏᄏᄏᄏᄏ', '▁주인공', '도', '▁별로고', '▁줄', '거리는', '▁진짜', '▁말도', '▁안돼', '...']

# %%
import pandas as pd

# %%
# 모델 생성을 위해 데이터프레임 형태로 데이터 불러오기
train_data = pd.read_table('data/ratings_train.txt')
test_data = pd.read_table('data/ratings_test.txt')

# %%
train_data
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 3 columns]

# %%
test_data
# Out:
#             id                                           document  label
# 0      6270596                                                굳 ㅋ      1
# 1      9274899                               GDNTOPCLASSINTHECLUB      0
# 2      8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3      6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...        ...                                                ...    ...
# 49995  4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 49997  9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 49999  6070594                                         마무리는 또 왜이래      0
#
# [50000 rows x 3 columns]

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.models import load_model

# %%
# 단어 개수와 최대 길이 지정
vocab_size = 8000
max_len = 20

# %%
# 패딩 및 최대길이 초과 대상 자르기 함수
def preprocess_sentence(sentence, model, max_len=max_len):
    tokens = model.encode_as_ids(sentence)  
    if len(tokens) < max_len:
        tokens = tokens + [0] * (max_len - len(tokens))  # 패딩
    else:
        tokens = tokens[:max_len]  # 최대 길이 자르기
    return np.array(tokens)

# %%
# NaN 값 또는 비문자열 데이터를 제거
train_data = train_data[train_data['document'].apply(lambda x: isinstance(x, str))]
train_data = train_data.dropna(subset=['document'])
test_data = test_data[test_data['document'].apply(lambda x: isinstance(x, str))]
test_data = test_data.dropna(subset=['document'])

# %%
# 학습 데이터 전처리 수행
data_ngram = np.array([preprocess_sentence(sentence, sp_ngram) for sentence in train_data['document']])
data_bpe = np.array([preprocess_sentence(sentence, sp_bpe) for sentence in train_data['document']])
labels = np.array(train_data['label'])

# %%
# 테스트 데이터 전처리 수행
test_data_ngram = np.array([preprocess_sentence(sentence, sp_ngram) for sentence in test_data['document']])
test_data_bpe = np.array([preprocess_sentence(sentence, sp_bpe) for sentence in test_data['document']])
test_labels = np.array(test_data['label'])

# %%
from sklearn.model_selection import train_test_split

# %%
# 학습데이터 검증데이터 분리
train_data_ngram, val_data_ngram, train_labels_ngram, val_labels_ngram = train_test_split(
    data_ngram, labels, test_size=0.2, random_state=42
)
train_data_bpe, val_data_bpe, train_labels_bpe, val_labels_bpe = train_test_split(
    data_bpe, labels, test_size=0.2, random_state=42
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout

# %% [markdown]
# #### 실험 환경
# - 동일한 파라미터를 사용한 모델에서 토크나이징 방식만 ngram과 bpe로 나누어서 학습

# %%
#  콜백 함수 정의
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),  
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)  
]

# %%
# ngram 방식 사용을 위한 1D 합성곱 모델 정의
model_ngram = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len),
    Conv1D(64, 5, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model_ngram.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# ngram 방식 학습
history_ngram = model_ngram.fit(
    train_data_ngram, train_labels_ngram,
    epochs=20,
    batch_size=2,
    validation_data=(val_data_ngram, val_labels_ngram),
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 59998/59998 [==============================] - 194s 3ms/step - loss: 0.4206 - accuracy: 0.8081 - val_loss: 0.3643 - val_accuracy: 0.8388
# Epoch 2/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.3364 - accuracy: 0.8577 - val_loss: 0.3568 - val_accuracy: 0.8447
# Epoch 3/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.2854 - accuracy: 0.8852 - val_loss: 0.3658 - val_accuracy: 0.8437
# Epoch 4/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.2321 - accuracy: 0.9102 - val_loss: 0.4176 - val_accuracy: 0.8345
# Epoch 5/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.1816 - accuracy: 0.9343 - val_loss: 0.5115 - val_accuracy: 0.8211
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/20
# 59998/59998 [==============================] - 189s 3ms/step - loss: 0.1010 - accuracy: 0.9649 - val_loss: 0.6141 - val_accuracy: 0.8184
# Epoch 7/20
# 59998/59998 [==============================] - 209s 3ms/step - loss: 0.0689 - accuracy: 0.9774 - val_loss: 0.8184 - val_accuracy: 0.8181

# %%
# 학습과정 그래프 출력
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_ngram.history['loss'], label='train_loss', marker='o')
plt.plot(history_ngram.history['val_loss'], label='val_loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('ngram Loss')
plt.legend()
plt.grid(True)

# 정확도 (Accuracy) 그래프
plt.subplot(1, 2, 2)
plt.plot(history_ngram.history['accuracy'], label='train_acc', marker='o')
plt.plot(history_ngram.history['val_accuracy'], label='val_acc', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('ngram Accuracy')
plt.legend()
plt.grid(True)

# 그래프 보여주기
plt.tight_layout()
plt.show()

# %%
# 테스트 데이터 예측 결과 확인
predictions_ngram = model_ngram.predict(test_data_ngram)

# 출력 개수를 10개로 제한
for i, sentence in enumerate(test_data['document'][:10]):
    sentiment = "긍정" if predictions_ngram[i] > 0.5 else "부정"
    print(f"문장: {sentence}")
    print(f"예측 점수: {predictions_ngram[i][0]:.4f} => {sentiment}\n")
# Out:
# 문장: 굳 ㅋ
# 예측 점수: 0.9988 => 긍정
#
# 문장: GDNTOPCLASSINTHECLUB
# 예측 점수: 0.6424 => 긍정
#
# 문장: 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아
# 예측 점수: 0.7890 => 긍정
#
# 문장: 지루하지는 않은데 완전 막장임... 돈주고 보기에는....
# 예측 점수: 0.0166 => 부정
#
# 문장: 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??
# 예측 점수: 0.0442 => 부정
#
# 문장: 음악이 주가 된, 최고의 음악영화
# 예측 점수: 0.9802 => 긍정
#
# 문장: 진정한 쓰레기
# 예측 점수: 0.0219 => 부정
#
# 문장: 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다
# 예측 점수: 0.4832 => 부정
#
# 문장: 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다
# 예측 점수: 0.0010 => 부정
#
# 문장: 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..
# 예측 점수: 0.8856 => 긍정

# %%
# 테스트 데이터 평가
test_loss_ngram, test_accuracy_ngram = model_ngram.evaluate(test_data_ngram, test_labels)
print(f"테스트 손실: {test_loss_ngram:.4f}, 테스트 정확도: {test_accuracy_ngram:.4f}")
# Out:
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3673 - accuracy: 0.8406
# 테스트 손실: 0.3673, 테스트 정확도: 0.8406

# %%
# bpe 방식 사용을 위한 1D 합성곱 모델 정의
model_bpe = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len),
    Conv1D(64, 5, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model_bpe.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# bpe 방식 학습
history_bpe = model_bpe.fit(
    train_data_bpe, train_labels_bpe,
    epochs=20,
    batch_size=2,
    validation_data=(val_data_bpe, val_labels_bpe),
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.4173 - accuracy: 0.8117 - val_loss: 0.3690 - val_accuracy: 0.8357
# Epoch 2/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.3372 - accuracy: 0.8593 - val_loss: 0.3628 - val_accuracy: 0.8457
# Epoch 3/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.2835 - accuracy: 0.8873 - val_loss: 0.3759 - val_accuracy: 0.8451
# Epoch 4/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.2241 - accuracy: 0.9158 - val_loss: 0.4533 - val_accuracy: 0.8388
# Epoch 5/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.1652 - accuracy: 0.9407 - val_loss: 0.5123 - val_accuracy: 0.8267
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.0858 - accuracy: 0.9710 - val_loss: 0.7681 - val_accuracy: 0.8179
# Epoch 7/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.0536 - accuracy: 0.9822 - val_loss: 0.9159 - val_accuracy: 0.8158

# %%
# 학습과정 그래프 출력
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_bpe.history['loss'], label='train_loss', marker='o')
plt.plot(history_bpe.history['val_loss'], label='val_loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('bpe Loss')
plt.legend()
plt.grid(True)

# 정확도 (Accuracy) 그래프
plt.subplot(1, 2, 2)
plt.plot(history_bpe.history['accuracy'], label='train_acc', marker='o')
plt.plot(history_bpe.history['val_accuracy'], label='val_acc', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('bpe Accuracy')
plt.legend()
plt.grid(True)

# 그래프 보여주기
plt.tight_layout()
plt.show()

# %%
# 테스트 데이터 예측 결과 확인
predictions_bpe = model_bpe.predict(test_data_bpe)

# 출력 개수를 10개로 제한
for i, sentence in enumerate(test_data['document'][:10]):
    sentiment = "긍정" if predictions_bpe[i] > 0.5 else "부정"
    print(f"문장: {sentence}")
    print(f"예측 점수: {predictions_bpe[i][0]:.4f} => {sentiment}\n")
# Out:
# 문장: 굳 ㅋ
# 예측 점수: 0.9894 => 긍정
#
# 문장: GDNTOPCLASSINTHECLUB
# 예측 점수: 0.5506 => 긍정
#
# 문장: 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아
# 예측 점수: 0.4325 => 부정
#
# 문장: 지루하지는 않은데 완전 막장임... 돈주고 보기에는....
# 예측 점수: 0.0000 => 부정
#
# 문장: 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??
# 예측 점수: 0.0678 => 부정
#
# 문장: 음악이 주가 된, 최고의 음악영화
# 예측 점수: 0.9779 => 긍정
#
# 문장: 진정한 쓰레기
# 예측 점수: 0.0007 => 부정
#
# 문장: 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다
# 예측 점수: 0.0461 => 부정
#
# 문장: 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다
# 예측 점수: 0.0001 => 부정
#
# 문장: 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..
# 예측 점수: 0.6516 => 긍정

# %%
# 모델 평가
test_loss_bpe, test_accuracy_bpe = model_bpe.evaluate(test_data_bpe, test_labels)
print(f"테스트 손실: {test_loss_bpe:.4f}, 테스트 정확도: {test_accuracy_bpe:.4f}")
# Out:
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3677 - accuracy: 0.8418
# 테스트 손실: 0.3677, 테스트 정확도: 0.8418

# %% [markdown]
# #### 실험 환경
# - 동일한 파라미터를 사용한 모델에서 토크나이징 방식을 ngram과 bpe로 나누어서 학습
# - 기존 단어사전 크기를 8,000에서 5,000으로 감소시킴

# %%
# ngram 방식 + 5000개 단어사전 사용을 위한 1D 합성곱 모델 정의
model_ngram_5000 = Sequential([
    Embedding(input_dim=5000, output_dim=128, input_length=max_len),
    Conv1D(64, 5, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model_ngram_5000.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# ngram + 5000개 단어사전으로 학습
history_ngram_5000 = model_ngram_5000.fit(
    train_data_ngram, train_labels_ngram,
    epochs=20,
    batch_size=2,
    validation_data=(val_data_ngram, val_labels_ngram),
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.4470 - accuracy: 0.7926 - val_loss: 0.3983 - val_accuracy: 0.8145
# Epoch 2/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.3856 - accuracy: 0.8301 - val_loss: 0.3906 - val_accuracy: 0.8224
# Epoch 3/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.3454 - accuracy: 0.8514 - val_loss: 0.4142 - val_accuracy: 0.8226
# Epoch 4/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.3041 - accuracy: 0.8725 - val_loss: 0.4339 - val_accuracy: 0.8178
# Epoch 5/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.2628 - accuracy: 0.8937 - val_loss: 0.5086 - val_accuracy: 0.8137
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.1808 - accuracy: 0.9273 - val_loss: 0.6182 - val_accuracy: 0.8038
# Epoch 7/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.1395 - accuracy: 0.9451 - val_loss: 0.8050 - val_accuracy: 0.8002

# %%
# 학습과정 그래프 출력
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_ngram_5000.history['loss'], label='train_loss', marker='o')
plt.plot(history_ngram_5000.history['val_loss'], label='val_loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('ngram_5000 Loss')
plt.legend()
plt.grid(True)

# 정확도 (Accuracy) 그래프
plt.subplot(1, 2, 2)
plt.plot(history_ngram_5000.history['accuracy'], label='train_acc', marker='o')
plt.plot(history_ngram_5000.history['val_accuracy'], label='val_acc', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('ngram_5000 Accuracy')
plt.legend()
plt.grid(True)

# 그래프 보여주기
plt.tight_layout()
plt.show()

# %%
#  테스트 데이터로 예측
predictions_ngram_5000 = model_ngram_5000.predict(test_data_ngram)

for i, sentence in enumerate(test_data['document'][:10]):
    sentiment = "긍정" if predictions_ngram_5000[i] > 0.5 else "부정"
    print(f"문장: {sentence}")
    print(f"예측 점수: {predictions_ngram_5000[i][0]:.4f} => {sentiment}\n")
# Out:
# 문장: 굳 ㅋ
# 예측 점수: 0.9909 => 긍정
#
# 문장: GDNTOPCLASSINTHECLUB
# 예측 점수: 0.7845 => 긍정
#
# 문장: 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아
# 예측 점수: 0.6433 => 긍정
#
# 문장: 지루하지는 않은데 완전 막장임... 돈주고 보기에는....
# 예측 점수: 0.0263 => 부정
#
# 문장: 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??
# 예측 점수: 0.1695 => 부정
#
# 문장: 음악이 주가 된, 최고의 음악영화
# 예측 점수: 0.9663 => 긍정
#
# 문장: 진정한 쓰레기
# 예측 점수: 0.0027 => 부정
#
# 문장: 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다
# 예측 점수: 0.2794 => 부정
#
# 문장: 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다
# 예측 점수: 0.0016 => 부정
#
# 문장: 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..
# 예측 점수: 0.8434 => 긍정

# %%
# 모델 평가
test_loss_ngram, test_accuracy_ngram = model_ngram_5000.evaluate(test_data_ngram, test_labels)
print(f"테스트 손실: {test_loss_ngram:.4f}, 테스트 정확도: {test_accuracy_ngram:.4f}")
# Out:
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3980 - accuracy: 0.8178
# 테스트 손실: 0.3980, 테스트 정확도: 0.8178

# %%
# bpe 방식 + 5000개 단어사전 사용을 위한 1D 합성곱 모델 정의
model_bpe_5000 = Sequential([
    Embedding(input_dim=5000, output_dim=128, input_length=max_len),
    Conv1D(64, 5, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model_bpe_5000.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# bpe + 5000개 단어사전으로 학습
history_bpe_5000 = model_bpe_5000.fit(
    train_data_ngram, train_labels_ngram,
    epochs=20,
    batch_size=2,
    validation_data=(val_data_bpe, val_labels_bpe),
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.4439 - accuracy: 0.7916 - val_loss: 0.9760 - val_accuracy: 0.5031
# Epoch 2/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.3809 - accuracy: 0.8321 - val_loss: 1.0609 - val_accuracy: 0.5036
# Epoch 3/20
# 59998/59998 [==============================] - 192s 3ms/step - loss: 0.3426 - accuracy: 0.8544 - val_loss: 0.9968 - val_accuracy: 0.5035
# Epoch 4/20
# 59998/59998 [==============================] - 191s 3ms/step - loss: 0.2996 - accuracy: 0.8762 - val_loss: 1.1049 - val_accuracy: 0.5048
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.2142 - accuracy: 0.9145 - val_loss: 1.2970 - val_accuracy: 0.5071
# Epoch 6/20
# 59998/59998 [==============================] - 190s 3ms/step - loss: 0.1650 - accuracy: 0.9351 - val_loss: 1.7101 - val_accuracy: 0.5041

# %%
# 학습과정 그래프 출력
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_bpe_5000.history['loss'], label='train_loss', marker='o')
plt.plot(history_bpe_5000.history['val_loss'], label='val_loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('bpe_5000 Loss')
plt.legend()
plt.grid(True)

# 정확도 (Accuracy) 그래프
plt.subplot(1, 2, 2)
plt.plot(history_bpe_5000.history['accuracy'], label='train_acc', marker='o')
plt.plot(history_bpe_5000.history['val_accuracy'], label='val_acc', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('bpe_5000 Accuracy')
plt.legend()
plt.grid(True)

# 그래프 보여주기
plt.tight_layout()
plt.show()

# %%
# 테스트 데이터 예측 결과 확인
predictions_bpe_5000 = model_bpe_5000.predict(test_data_bpe)

# 출력 개수를 10개로 제한
for i, sentence in enumerate(test_data['document'][:10]):
    sentiment = "긍정" if predictions_bpe_5000[i] > 0.5 else "부정"
    print(f"문장: {sentence}")
    print(f"예측 점수: {predictions_bpe_5000[i][0]:.4f} => {sentiment}\n")
# Out:
# 문장: 굳 ㅋ
# 예측 점수: 0.5839 => 긍정
#
# 문장: GDNTOPCLASSINTHECLUB
# 예측 점수: 0.4252 => 부정
#
# 문장: 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아
# 예측 점수: 0.9822 => 긍정
#
# 문장: 지루하지는 않은데 완전 막장임... 돈주고 보기에는....
# 예측 점수: 0.7974 => 긍정
#
# 문장: 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??
# 예측 점수: 0.2353 => 부정
#
# 문장: 음악이 주가 된, 최고의 음악영화
# 예측 점수: 0.5359 => 긍정
#
# 문장: 진정한 쓰레기
# 예측 점수: 0.3767 => 부정
#
# 문장: 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다
# 예측 점수: 0.4197 => 부정
#
# 문장: 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다
# 예측 점수: 0.8299 => 긍정
#
# 문장: 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..
# 예측 점수: 0.4500 => 부정

# %%
# 모델 평가
test_loss_bpe, test_accuracy_bpe = model_bpe_5000.evaluate(test_data_bpe, test_labels)
print(f"테스트 손실: {test_loss_bpe:.4f}, 테스트 정확도: {test_accuracy_bpe:.4f}")
# Out:
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.9585 - accuracy: 0.5148
# 테스트 손실: 0.9585, 테스트 정확도: 0.5148

# %% [markdown]
# ### 테스트 결과
#
# #### ngram 방식 + 단어집합 수 8,000
# - 2번째 에포크, 훈련 정확도 : 0.8577, 검증 정확도 : 0.8447, 테스트 정확도 : 0.8406
#
# #### bpe 방식 + 단어집합 수 8,000
# - 2번째 에포크, 훈련 정확도 : 0.8593, 검증 정확도 : 0.8457, 테스트 정확도 : 0.8418
#
# #### ngram 방식 + 단어집합 수 5,000
# - 3번째 에포크, 훈련 정확도 : 0.8514, 검증 정확도 : 0.8226, 테스트 정확도 : 0.8178
#
# #### bpe 방식 + 단어집합 수 5,000
# - 5번째 에포크, 훈련 정확도 : 0.8577, 검증 정확도 : 0.8447, 테스트 정확도 : 0.5148

# %% [markdown]
# ### 결론
#
# - bpe방식에 상대적으로 적은 5,000개의 단어집합을 사용한 모델은 검증정확도 기준 5번째 에포크에서 최고 성능이 나타났음
# - 나머지 모델들(ngram+8,000, bpe+8000, ngram+5000) 모두 검증 정확도 기준 2~3 에포크에서 최고 성능이 나타남
# - ngram방식은 단어집합의 개수 변화에 영향을 덜 받음(테스트 정확도 기준, 0.8406 -> 0.8178)
# - bpe방식은 단어집합 개수 변화에 큰 영향을 받음(테스트 정확도 기준, 0.8418 -> 0.5148)
# ##### - 학습데이터의 단어 집합이 적은 경우 ngram 방식을 사용하는 것이 유리할 것으로 보임
#
# ####
# - 학습된 단어사전에 의미없는 1단어 문자도 존재함(인덱스 7436~). 미리 확인하고 단어집합 수를 정하는 것이 모델 성능에 도움이 될듯
# ![image.png](attachment:image.png)
